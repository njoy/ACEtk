# %%
import os

# a recursive function to find all files with a given extension in a directory
def getFilesInFolder( directory, extension ) :

    files = os.listdir( directory )
    everything = list()

    for entry in files :

        file = os.path.join( directory, entry )

        if os.path.isdir( file ) :

            everything += getFilesInFolder( file, extension )

        else :

            everything.append( file )

    return [ file for file in everything if file.endswith( extension ) ]

# %%
import ACEtk
import time

path = 'resources'
files = getFilesInFolder( path, 'nc' )
failed = []

start = time.perf_counter()
for file in files :

    try :

        tape = ACEtk.ContinuousEnergyTable.from_file( file )

    except :

        print( 'FAILED', file )
        failed.append( file )

end = time.perf_counter()

print( '-------------------------' )
print( '{:4} files'.format( len( files ) ) )
print( '{:4} failed'.format( len( failed ) ) )
print( 'elapsed time = {:.3} s'.format( end - start ) )
print( '-------------------------' )
# Out:
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.801nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.805nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.802nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.806nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.803nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.800nc
# FAILED /Users/wim/Projects/libraries/ace/Lib80x/B/5010.804nc
# -------------------------
# 3892 files
#    7 failed
# elapsed time = 1.07e+02 s
# -------------------------
